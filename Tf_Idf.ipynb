# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['going', 'thru', 'different', 'feelingwaverin...
# 1                    ['may', 'call', 'later', 'pls']
# 2  ['think', 'û', 'waiting', 'bus', 'inform', 'ge...
# 3              ['aight', 'well', 'keep', 'informed']
# 4                                      ['u', 'call']

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'going': 3313,
#  'thru': 7279,
#  'different': 2429,
#  'feelingwavering': 2932,
#  'decisions': 2318,
#  'coping': 2095,
#  'individualtime': 3836,
#  'heal': 3509,
#  'everything': 2793,
#  'believe': 1370,
#  'may': 4623,
#  'call': 1664,
#  'later': 4240,
#  'pls': 5572,
#  'think': 7246,
#  'waiting': 7775,
#  'bus': 1623,
#  'inform': 3842,
#  'get': 3251,
#  'ever': 2785,
#  'aight': 939,
#  'well': 7871,
#  'keep': 4092,
#  'informed': 3844,
#  '2p': 451,
#  'per': 5457,
#  'min': 4727,
#  'germany': 3250,
#  '08448350055': 60,
#  'bt': 1589,
#  'line': 4340,
#  'check': 1831,
#  'planettalkinstantcom': 5547,
#  'info': 3841,
#  'ts': 7466,
#  'cs': 2178,
#  'text': 7186,
#  'stop': 6882,
#  'opt': 5276,
#  'talk': 7091,
#  'oh': 5204,
#  'ok': 5211,
#  'wats': 7827,
#  'ur': 7607,
#  'email': 2691,
#  'tell': 7153,
#  'stay': 6842,
#  'yeah': 8160,
#  'tough': 7403,
#  'optimistic': 5278,
#  'things': 7245,
#  'improve': 3808,
#  'month': 4833,
#  'im': 3787,
#  'glad': 3284,
#  'didnt': 2417,
#  'find': 2981,
#  'totally': 7399,
#  'disagreeable': 2457,
#  'lol': 4399,
#  'sleepingand': 6577,
#  'surfing': 7017,
#  'go': 3296,
#  'buy': 1633,
#  'wif': 7928,
#  'meet': 4649,
#  'wet': 7890,
#  'right': 6114,
#  'selected': 6342,
#  '250': 405,
#  'top': 7384,
#  'british': 1568,
#  'hotels': 3668,
#  'nothing': 5110,
#  'holiday': 3627,
#  'worth': 8042,
#  '350': 489,
#  'claim': 1901,
#  'london': 4402,
#  '02072069400': 9,
#  'bx': 1641,
#  '526': 597,
#  'sw73ss': 7031,
#  'wil': 7935,
#  'ltgt': 4470,
#  'minutes': 4748,
#  'got': 3343,
#  'space': 6718,
#  'diet': 2423,
#  'flew': 3023,
#  'window': 7944,
#  'drink': 2567,
#  'plenty': 5569,
#  'water': 7822,
#  'late': 4236,
#  'tellmiss': 7155,
#  'way': 7829,
#  'coming': 1993,
#  'whatever': 7896,
#  'want': 7799,
#  'wonder': 8002,
#  'cos': 2106,
#  'dun': 2604,
#  'rem': 6012,
#  'seeing': 6329,
#  'silver': 6520,
#  'car': 1722,
#  'thk': 7254,
#  'saw': 6266,
#  'black': 1429,
#  'one': 5237,
#  'ps': 5806,
#  'grown': 3400,
#  'da': 2225,
#  'happy': 3480,
#  'sit': 6545,
#  'together': 7347,
#  'na': 4941,
#  'lor': 4419,
#  'change': 1803,
#  'suntec': 6995,
#  'wat': 7817,
#  'time': 7300,
#  'great': 3379,
#  'never': 5014,
#  'better': 1389,
#  'day': 2279,
#  'gives': 3282,
#  'even': 2779,
#  'reasons': 5945,
#  'thank': 7203,
#  'god': 3303,
#  'someone': 6661,
#  'know': 4162,
#  'asked': 1162,
#  'dating': 2270,
#  'service': 6380,
#  'contact': 2065,
#  'cant': 1715,
#  'guess': 3417,
#  '09058097189': 179,
#  'revealed': 6098,
#  'pobox': 5584,
#  'ls15hb': 4462,
#  '150p': 309,
#  'misplaced': 4757,
#  'number': 5138,
#  'sending': 6359,
#  'texts': 7197,
#  'old': 5227,
#  'wondering': 8004,
#  'ive': 3949,
#  'heard': 3512,
#  'year': 8161,
#  'best': 1383,
#  'mcat': 4628,
#  'atlanta': 1183,
#  'friends': 3139,
#  'kkim': 4148,
#  'tirunelvali': 7312,
#  'week': 7856,
#  'see': 6327,
#  'uncle': 7543,
#  'already': 985,
#  'spend': 6748,
#  'amount': 1010,
#  'taking': 7089,
#  'dress': 2564,
#  'moneyi': 4823,
#  'give': 3280,
#  'feb': 2924,
#  'said': 6221,
#  'many': 4572,
#  'morning': 4845,
#  'really': 5940,
#  'wanted': 7801,
#  'say': 6267,
#  'good': 3324,
#  'love': 4440,
#  'beautiful': 1341,
#  'library': 4310,
#  'lemme': 4288,
#  'whats': 7897,
#  'come': 1984,
#  'guoyang': 3426,
#  'told': 7352,
#  'however': 3682,
#  'suggest': 6975,
#  'stays': 6846,
#  'able': 811,
#  'ors': 5301,
#  'every': 2786,
#  'stool': 6881,
#  'wonders': 8005,
#  'world': 8027,
#  '7th': 685,
#  '6th': 657,
#  'style': 6944,
#  '5th': 618,
#  'smile': 6611,
#  '4th': 578,
#  'personality': 5476,
#  '3rd': 515,
#  'nature': 4968,
#  '2nd': 444,
#  'sms': 6623,
#  '1st': 363,
#  'lovely': 4444,
#  'friendship': 3141,
#  'dear': 2296,
#  'ill': 3785,
#  'back': 1260,
#  'smiling': 6615,
#  'crazy': 2152,
#  'away': 1234,
#  'grins': 3389,
#  'press': 5717,
#  'conference': 2041,
#  'story': 6897,
#  'returned': 6095,
#  'hes': 3564,
#  'saying': 6270,
#  'order': 5289,
#  'hi': 3573,
#  'test': 7180,
#  'rd': 5919,
#  'miss': 4758,
#  'ya': 8147,
#  'need': 4988,
#  'please': 5564,
#  'dont': 2525,
#  'like': 4328,
#  'took': 7376,
#  'tablets': 7072,
#  'reaction': 5926,
#  'ahhhhjust': 930,
#  'woken': 7996,
#  'uphad': 7596,
#  'bad': 1262,
#  'dream': 2558,
#  'thoso': 7261,
#  'anything': 1063,
#  'comedy': 1985,
#  'night': 5039,
#  'problem': 5756,
#  'frm': 3146,
#  'matter': 4613,
#  'fine': 2984,
#  'imma': 3796,
#  'somethin': 6665,
#  'getting': 3259,
#  'hungry': 3723,
#  'heart': 3514,
#  'empty': 2702,
#  'without': 7971,
#  'mind': 4730,
#  'wisdom': 7959,
#  'eyes': 2857,
#  'dreams': 2560,
#  'amp': 1011,
#  'life': 4316,
#  'frnds': 3148,
#  'alwys': 997,
#  'touch': 7401,
#  'sweet': 7044,
#  'send': 6356,
#  'chat': 1821,
#  '86688': 742,
#  'lets': 4300,
#  '150pmsg': 317,
#  'rcvd': 5918,
#  'hgsuite3422landsroww1j6hl': 3571,
#  'ldn': 4260,
#  '18': 341,
#  'years': 8162,
#  'alle': 975,
#  'moneeppolum': 4820,
#  'oru': 5303,
#  'pole': 5608,
#  'allalo': 974,
#  'word': 8013,
#  'checkmate': 1834,
#  'chess': 1849,
#  'comes': 1988,
#  'persian': 5472,
#  'phrase': 5507,
#  'shah': 6409,
#  'maat': 4512,
#  'means': 4636,
#  'king': 4130,
#  'dead': 2289,
#  'goodmorning': 3329,
#  'skateboarding': 6557,
#  'despite': 2384,
#  'fact': 2865,
#  'gets': 3255,
#  'thrown': 7277,
#  'winds': 7946,
#  'bandages': 1278,
#  'shit': 6449,
#  'arms': 1129,
#  'five': 3008,
#  'new': 5017,
#  'local': 4382,
#  'dates': 2269,
#  'area': 1114,
#  'lots': 4430,
#  'people': 5455,
#  'registered': 5997,
#  'reply': 6047,
#  'date': 2267,
#  'start': 6827,
#  'wwwflirtpartyus': 8090,
#  'replys150': 6049,
#  'place': 5537,
#  'points': 5605,
#  'cultures': 2194,
#  'module': 4807,
#  'specific': 6737,
#  'regards': 5995,
#  'jaklin': 3966,
#  'idk': 3771,
#  'fuck': 3161,
#  'dance': 2245,
#  'river': 6136,
#  'babe': 1252,
#  'sooooo': 6690,
#  'much': 4897,
#  'wish': 7961,
#  'sleep': 6574,
#  'bed': 1350,
#  'lonely': 4404,
#  'work': 8019,
#  '07801543489': 32,
#  'guaranteed': 3411,
#  'latests': 4243,
#  'nokia': 5081,
#  'phone': 5497,
#  '40gb': 532,
#  'ipod': 3907,
#  'mp3': 4870,
#  'player': 5555,
#  '500': 590,
#  'prize': 5749,
#  'txt': 7504,
#  'wordcollect': 8014,
#  'no83355': 5066,
#  'tcllc': 7122,
#  'nyusa': 5158,
#  '150pmt': 320,
#  'msgrcvd18': 4880,
#  'fishrman': 3005,
#  'woke': 7995,
#  'early': 2622,
#  'mrng': 4874,
#  'dark': 2254,
#  'waited': 7772,
#  'found': 3099,
#  'sack': 6212,
#  'ful': 3170,
#  'stones': 6880,
#  'strtd': 6922,
#  'throwin': 7276,
#  'thm': 7256,
#  'in2': 3810,
#  'sea': 6308,
#  'pass': 5411,
#  'atlast': 1184,
#  'jus': 4055,
#  '1stone': 366,
#  'sun': 6987,
#  'rose': 6164,
#  'tht': 7282,
#  'nt': 5134,
#  'diamonds': 2411,
#  'moraldont': 4841,
#  'wake': 7778,
#  'id': 3762,
#  'thats': 7217,
#  'sign': 6513,
#  'track': 7410,
#  'record': 5967,
#  'reading': 5930,
#  'women': 7999,
#  'hmph': 3613,
#  'head': 3502,
#  'big': 1402,
#  'baller': 1274,
#  'hello': 3533,
#  'peach': 5442,
#  'cake': 1654,
#  'tasts': 7106,
#  'lush': 4486,
#  'mobile': 4795,
#  'added': 864,
#  'list': 4356,
#  'wwwfullonsmscom': 8091,
#  'free': 3110,
#  'visit': 7722,
#  'fullonsmscom': 3173,
#  'usual': 7638,
#  'ard': 1113,
#  '10': 249,
#  'smth': 6629,
#  'try': 7462,
#  'making': 4552,
#  'another': 1042,
#  'butt': 1629,
#  'staff': 6809,
#  'name': 4950,
#  'class': 1909,
#  'us': 7621,
#  'dunno': 2606,
#  'dad': 2230,
#  'home': 3633,
#  'bring': 1562,
#  'lunch': 4484,
#  'yup': 8232,
#  'reach': 5921,
#  'school': 6283,
#  'cine': 1896,
#  'plaza': 5562,
#  'mah': 4536,
#  'fantasy': 2898,
#  'football': 3066,
#  'tv': 7492,
#  'sky': 6566,
#  'gamestar': 3199,
#  'active': 855,
#  'play': 5553,
#  '250k': 406,
#  'team': 7134,
#  'scoring': 6290,
#  'starts': 6832,
#  'saturday': 6258,
#  'register': 5996,
#  'nowsky': 5129,
#  '88088': 757,
#  'tee': 7143,
#  'hee': 3525,
#  'lecture': 4277,
#  'cheery': 1839,
#  'bye': 1646,
#  '09058091854': 170,
#  'po': 5583,
#  'box385': 1515,
#  'm6': 4506,
#  '6wu': 659,
#  'wen': 7876,
#  'lovable': 4439,
#  'bcums': 1333,
#  'angry': 1030,
#  'wid': 7926,
#  'dnt': 2490,
#  'take': 7084,
#  'seriously': 6377,
#  'coz': 2136,
#  'childish': 1867,
#  'true': 7454,
#  'showing': 6488,
#  'deep': 2326,
#  'affection': 896,
#  'care': 1726,
#  'luv': 4488,
#  'kettoda': 4103,
#  'manda': 4564,
#  'nice': 5031,
#  'would': 8047,
#  'okay': 5212,
#  'john': 4016,
#  'let': 4299,
#  'nigeria': 5038,
#  'dollars': 2518,
#  '2years': 464,
#  'sent': 6367,
#  'strain': 6901,
#  'plan': 5543,
#  'pay': 5431,
#  'dime': 2438,
#  'expect': 2830,
#  'practical': 5677,
#  'something': 6666,
#  'door': 2529,
#  'possession': 5639,
#  'especially': 2759,
#  'first': 3003,
#  'offense': 5182,
#  'dizzamn': 2485,
#  'ask': 1160,
#  'suitemates': 6978,
#  'omg': 5232,
#  'scream': 6298,
#  'weighed': 7863,
#  'lost': 4427,
#  'weight': 7864,
#  'woohoo': 8009,
#  'welcome': 7869,
#  'age': 912,
#  'gender': 3237,
#  'begin': 1363,
#  'eg': 2661,
#  '24m': 402,
#  'hear': 3511,
#  'divorce': 2483,
#  'barbie': 1289,
#  'kens': 4097,
#  'stuff': 6934,
#  'unique': 7565,
#  'enough': 2727,
#  '30th': 476,
#  'august': 1203,
#  'wwwareyouuniquecouk': 8081,
#  'lei': 4286,
#  'gud': 3412,
#  'hav': 3495,
#  'arun': 1150,
#  'transfr': 7427,
#  'amt': 1016,
#  'ringtone': 6123,
#  'club': 1940,
#  'uk': 7529,
#  'singles': 6535,
#  'chart': 1816,
#  'choose': 1882,
#  'quality': 5850,
#  'message': 4691,
#  'charge': 1809,
#  'network': 5010,
#  'operator': 5266,
#  '80488biz': 698,
#  'hey': 3567,
#  'watching': 7820,
#  'movie': 4866,
#  'tonight': 7370,
#  'prob': 5754,
#  'next': 5025,
#  'upto': 7606,
#  '50': 589,
#  'calls': 1689,
#  'standard': 6817,
#  'activate': 854,
#  '9061100010': 780,
#  'wire3net': 7958,
#  '1st4terms': 364,
#  'pobox84': 5595,
#  'm26': 4503,
#  '3uz': 519,
#  'cost': 2108,
#  '150': 304,
#  'mobcudb': 4794,
#  'meeting': 4652,
#  'reserve': 6065,
#  'ticket': 7291,
#  'eve': 2776,
#  'chennai': 1844,
#  'thirunelvali': 7252,
#  'sunday': 6988,
#  'evei': 2778,
#  'netno': 5009,
#  'availablei': 1215,
#  'book': 1481,
#  'tackle': 7073,
#  'mu': 4896,
#  'seconds': 6316,
#  'road': 6137,
#  'gonna': 3322,
#  'massive': 4597,
#  'pain': 5365,
#  'ass': 1168,
#  'rather': 5906,
#  'involved': 3900,
#  'possible': 5643,
#  'sexy': 6396,
#  'followed': 3053,
#  'wither': 7969,
#  'eg23f': 2662,
#  'gay': 3217,
#  'men': 4673,
#  'eg23g': 2663,
#  'freemsg': 3117,
#  'videopic': 7698,
#  'fones': 3060,
#  'wild': 7936,
#  'pics': 5515,
#  'hurry': 3733,
#  'bored': 1493,
#  'xxx': 8140,
#  '150prcvd': 325,
#  'stop2stop': 6884,
#  'mr': 4872,
#  'owl': 5344,
#  'licks': 4312,
#  'reaching': 5924,
#  'homelove': 3636,
#  'lot': 4428,
#  'training': 7417,
#  'urgent': 7610,
#  'awarded': 1233,
#  '2000': 376,
#  'bonus': 1478,
#  'caller': 1681,
#  '5903': 604,
#  'final': 2976,
#  'landline': 4216,
#  '09064019788': 208,
#  'box42wr29c': 1518,
#  '150ppm': 324,
#  'important': 3802,
#  'information': 3843,
#  'orange': 5285,
#  'user': 7629,
#  'today': 7338,
#  'lucky': 4478,
#  'day2find': 2281,
#  'log': 4389,
#  'onto': 5250,
#  'httpwwwurawinnercom': 3703,
#  'theres': 7235,
#  'fantastic': 2897,
#  'surprise': 7020,
#  'awaiting': 1230,
#  'city': 1899,
#  'break': 1542,
#  'could': 2119,
#  'win': 7941,
#  '200': 375,
#  'summer': 6983,
#  'shopping': 6465,
#  'spree': 6785,
#  'wk': 7977,
#  'store': 6892,
#  '88039': 754,
#  'skilgme': 6558,
#  'tscs087147403231winawkage16': 7470,
#  '150perwksub': 312,
#  'make': 4548,
#  'appointment': 1092,
#  'thanx4': 7210,
#  'cer': 1788,
#  'catch': 1761,
#  'ave': 1220,
#  'often': 5200,
#  'soonc': 6685,
#  'diff': 2425,
#  'farm': 2900,
#  'shop': 6463,
#  'cheese': 1840,
#  'bit': 1423,
#  'gifts': 3268,
#  'trying': 7464,
#  'throw': 7275,
#  'cliff': 1923,
#  'shuhui': 6498,
#  'bought': 1504,
#  'rons': 6157,
#  'present': 5713,
#  'swatch': 7038,
#  'watch': 7818,
#  'tick': 7290,
#  'sorry': 6695,
#  'days': 2283,
#  'asking': 1164,
#  'gym': 3434,
#  'excuse': 2817,
#  'lazy': 4258,
#  'jog': 4014,
#  'datoday': 2272,
#  'also': 991,
#  'forgot': 3082,
#  'nutter': 5147,
#  'cutter': 2219,
#  'ctter': 2187,
#  'cttergg': 2188,
#  'cttargg': 2186,
#  'ctargg': 2183,
#  'ctagg': 2182,
#  'ie': 3774,
#  'battery': 1314,
#  'went': 7879,
#  'started': 6828,
#  'skye': 6567,
#  'audreys': 1202,
#  'status': 6841,
#  'yes': 8171,
#  'dint': 2447,
#  'doesnt': 2501,
#  'tomorrow': 7361,
#  'thus': 7287,
#  'shouldnt': 6478,
#  'smoke': 6618,
#  'okie': 5216,
#  '09066362231': 222,
#  '07xxxxxxxxx': 42,
#  '020603': 7,
#  'attempt': 1190,
#  'asap': 1152,
#  'moon': 4838,
#  'color': 1976,
#  'stars': 6825,
#  'musical': 4926,
#  'warm': 7806,
#  'peaceful': 5441,
#  'bears': 1339,
#  'pic': 5510,
#  'nick': 5034,
#  'tom': 7355,
#  'pete': 5480,
#  'dick': 2414,
#  'types': 7514,
#  'photo': 5503,
#  'upload': 7597,
#  '08718730666': 147,
#  '10pmin': 268,
#  '08712460324': 109,
#  'dude': 2598,
#  'parked': 5398,
#  'sunroof': 6992,
#  'popped': 5631,
#  'sux': 7027,
#  'sno': 6638,
#  'competition': 2008,
#  'yet': 8186,
#  'hadya': 3441,
#  'sapna': 6242,
#  'aunty': 1206,
#  'manege': 4568,
#  'yday': 8159,
#  'hogidhechinnu': 3618,
#  'full': 3172,
#  'weak': 7835,
#  'swalpa': 7032,
#  'agidhane': 920,
#  'joanna': 4009,
#  'feeling': 2931,
#  'anti': 1053,
#  'social': 6647,
#  'mmm': 4783,
#  'yummy': 8227,
#  'jolt': 4029,
#  'suzy': 7028,
#  'wishing': 7965,
#  'family': 2888,
#  'merry': 4687,
#  'mas': 4593,
#  'advance': 884,
#  'probably': 5755,
#  'couple': 2128,
#  'hours': 3672,
#  'tops': 7390,
#  'two': 7503,
#  'still': 6870,
#  'cash': 1751,
#  'def': 2331,
#  'ready': 5931,
#  'sir': 6540,
#  'enjoy': 2720,
#  'role': 6150,
#  'playing': 5560,
#  'shes': 6434,
#  'double': 2537,
#  'mins': 4741,
#  '1000': 251,
#  'txts': 7509,
#  'tariffs': 7103,
#  'latest': 4242,
#  'motorola': 4858,
#  'sonyericsson': 6682,
#  'bluetooth': 1463,
#  'mobileupd8': 4799,
#  '08000839402': 46,
#  'call2optouthf8': 1669,
#  'yeh': 8164,
#  'indians': 3833,
#  'tho': 7260,
#  'kane': 4074,
#  'shud': 6497,
#  'sometime': 6668,
#  'soon': 6684,
#  'mite': 4773,
#  'works': 8026,
#  'laugh': 4245,
#  'unsubscribe': 7585,
#  'mob': 4793,
#  'offer': 5183,
#  'package': 5356,
#  'term': 7170,
#  '54': 601,
#  'weeks': 7860,
#  'resubmit': 6089,
#  'request': 6054,
#  'expiry': 2841,
#  'themob': 7225,
#  'help': 3539,
#  'driving': 2575,
#  'raining': 5884,
#  'caught': 1765,
#  'mrt': 4875,
#  'station': 6840,
#  'nah': 4946,
#  'goes': 3308,
#  'usf': 7630,
#  'lives': 4369,
#  'around': 1133,
#  'though': 7264,
#  'ohi': 5206,
#  'fun': 3174,
#  'hahatake': 3445,
#  'remains': 6014,
#  'bro': 1570,
#  'amongst': 1008,
#  'bros': 1574,
#  'housemaid': 3675,
#  'murderer': 4921,
#  'man': 4558,
#  'murdered': 4920,
#  'th': 7200,
#  'january': 3974,
#  'public': 5817,
#  'govtinstituitions': 3351,
#  'closedincluding': 1932,
#  'post': 5646,
#  'officeunderstand': 5192,
#  'takes': 7087,
#  'part': 5401,
#  'wrc': 8052,
#  'rally': 5893,
#  'oz': 5352,
#  'lucozade': 4479,
#  'energy': 2712,
#  'le': 4262,
#  '61200': 628,
#  '25p': 409,
#  'packs': 5359,
#  'lucozadecoukwrc': 4480,
#  'itcould': 3930,
#  'torture': 7395,
#  'england': 2718,
#  'youll': 8207,
#  'rcv': 5917,
#  'msgs': 4881,
#  'svc': 7029,
#  'hardcore': 3482,
#  'services': 6381,
#  '69988': 647,
#  'must': 4927,
#  'verify': 7682,
#  'yr': 8224,
#  'interested': 3877,
#  'business': 1626,
#  'inside': 3864,
#  'ate': 1181,
#  'spageddies': 6721,
#  'gals': 3195,
#  'laughing': 4247,
#  'ah': 925,
#  'poop': 5625,
#  'looks': 4414,
#  'laptop': 4226,
#  'fixed': 3011,
#  'cuz': 2221,
#  'gpu': 3355,
#  'yun': 8228,
#  'ahnow': 932,
#  'wkg': 7980,
#  'wherebtw': 7906,
#  'nus': 5144,
#  'sc': 6274,
#  'ìï': 8251,
#  'wana': 7797,
#  'specialise': 6735,
#  'wad': 7763,
#  'initiate': 3852,
#  'understand': 7552,
#  'gr8': 3356,
#  'tones': 7364,
#  'str8': 6899,
#  '8007': 691,
#  'classic': 1911,
#  'hit': 3591,
#  'polys': 5618,
#  'nokia150p': 5082,
#  'poly200p': 5613,
#  '16': 336,
#  'taken': 7086,
#  'real': 5933,
#  'valentine': 7654,
#  'izzit': 3952,
#  'dropped': 2579,
#  'cell': 1784,
#  'stairs': 6811,
#  'seems': 6334,
#  'alright': 987,
#  'phews': 5492,
#  'use': 7625,
#  'foreign': 3073,
#  'stamps': 6815,
#  'kaiez': 4064,
#  'tuition': 7481,
#  'gee': 3231,
#  'second': 6314,
#  'option': 5280,
#  'sounds': 6709,
#  'beta': 1388,
#  'yan': 8151,
#  'jiu': 4006,
#  'den': 2357,
#  'msg': 4877,
#  'truth': 7460,
#  'gravity': 3375,
#  'read': 5927,
#  'carefully': 1731,
#  'feels': 2933,
#  'light': 4325,
#  'heavy': 3524,
#  'leaves': 4274,
#  'cool': 2091,
#  'youre': 8211,
#  'tyler': 7510,
#  'drop': 2578,
#  'total': 7398,
#  'quarter': 5851,
#  'last': 4233,
#  'thing': 7243,
#  'hurt': 3734,
#  'youd': 8201,
#  'embarassed': 2693,
#  'delete': 2345,
#  'tag': 7078,
#  'far': 2899,
#  'knew': 4159,
#  'wasnt': 7812,
#  'felt': 2938,
#  'shows': 6491,
#  'messy': 4703,
#  'wednesday': 7851,
#  'clean': 1914,
#  'skype': 6568,
#  'pictures': 5518,
#  'laundry': 4249,
#  'friend': 3137,
#  'house': 3673,
#  'underwear': 7555,
#  'bras': 1536,
#  'strewn': 6912,
#  'pillows': 5527,
#  'floor': 3033,
#  'else': 2688,
#  'used': 7626,
#  'least': 4271,
#  'boy': 1523,
#  'yo': 8193,
#  'quick': 5860,
#  'hppnss': 3687,
#  'tear': 7136,
#  'sorrow': 6693,
#  'mine': 4733,
#  'forevr': 3075,
#  'goodfriend': 3327,
#  'complete': 2014,
#  'gist': 3278,
#  'sweetheart': 7046,
#  'hope': 3649,
#  'kind': 4127,
#  'loads': 4378,
#  'biola': 1414,
#  'apparently': 1081,
#  'bffs': 1396,
#  'carly': 1741,
#  'plans': 5550,
#  'eastenders': 2632,
#  'quiz': 5866,
#  'flower': 3037,
#  'dot': 2536,
#  'compare': 2005,
#  'violet': 7715,
#  'tulip': 7483,
#  'lily': 4335,
#  '84025': 725,
#  'chance': 1801,
#  '100': 250,
#  'wkent150p16': 7979,
#  'private': 5746,
#  '2003': 378,
#  'account': 835,
#  'statement': 6838,
#  '07753741225': 27,
#  '800': 688,
#  'unredeemed': 7579,
#  '08715203677': 125,
#  'identifier': 3769,
#  'code': 1956,
#  '42478': 535,
#  'expires': 2840,
#  '241004': 399,
#  'macho': 4519,
#  'budget': 1600,
#  'bb': 1317,
#  'bold': 1473,
#  'samus': 6236,
#  'shoulders': 6477,
#  ...}

# %%
# How are these vectors stored?
X_train_vect[0]
# Out:
# <1x8259 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_train_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())
# Out:
# /home/acer/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.991 / Recall: 0.778 / Accuracy: 0.97
